# %% [markdown]
# # Problem 4
# ----
# Give the Big-O performance of the following homework problems:
# - Assignment 2, Problem 5 (Divisibile by 11)
# - Assignment 3, Problem 3 (encrypt and decrypt)
# - Assignment 3, Problem 5 (crack the code)
# - Assignment 4, Problem 5 (greatest common divisor)
#
# Support your answers with a succinct written statement.  In addition, please provide the URL to each assignment in you written statement.  For example:
# ```
# - Assignment 0, problem 0:
#   - O(N) The algorithm has to observe each member of the list to see if it is true.
#   - https://github.com/uchicago-codes/MPCS50101-2017-Winter-Sample/blob/master/problem1.py
# ```

# %%
- Assignment 2, Problem 5:
  - O(1) The algorithm checks if one number is divisible by 11
  - https://github.com/makunde/makunde_uchicago_python_homework_fall_2025/blob/main/assignment_2/problem_5.py
- Assignment 3, Problem 3:
  - O(n) The algorithm looks at n characters and looks for in in a dict with O(1) lookup time
  - https://github.com/uchicago-codes/mpcs50101-2025-autumn-assignment-3-makunde/blob/main/problem_3.py
- Assignment 3, Problem 5:
  - O(n) The algorithm has a fixed loop of 26 where there are 2 O(n) loops that are not nested inside of it
  - https://github.com/uchicago-codes/mpcs50101-2025-autumn-assignment-3-makunde/blob/main/problem_5.py
- Assignment 5, Problem 2 (this is the correct assignment for gcd):
  - O(log(n)) The algorithm divides n by m and calls itself with the remainder. This dividing makes it more efficient
  - https://github.com/uchicago-codes/mpcs50101-2025-autumn-assignment-5-makunde/blob/main/gcd_problem_2.py
